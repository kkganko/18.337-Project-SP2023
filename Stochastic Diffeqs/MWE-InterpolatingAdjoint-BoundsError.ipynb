# %%
import Pkg; Pkg.activate("."); Pkg.instantiate(verbose=true)
# Out:
#   Activating project at `~/6.337/18.337-Project-SP2023/Stochastic Diffeqs`

# %%
Pkg.status()
# Out:
#       Status `~/6.337/18.337-Project-SP2023/Stochastic Diffeqs/Project.toml`
#   [6e4b80f9] BenchmarkTools v1.3.2
#   [b0b7db55] ComponentArrays v0.13.12
#   [8f4d0f93] Conda v1.8.0
#   [aae7a2af] DiffEqFlux v1.54.0
#   [0c46a032] DifferentialEquations v7.7.0
#   [31c24e10] Distributions v0.25.91
#   [587475ba] Flux v0.13.16
#   [f6369f11] ForwardDiff v0.10.35
#   [bd48cda9] GraphRecipes v0.5.12
#   [86223c79] Graphs v1.8.0
#   [7073ff75] IJulia v1.24.0
#   [4138dd39] JLD v0.13.3
#   [b964fa9f] LaTeXStrings v1.3.0
#   [b2108857] Lux v0.4.53
#   [429524aa] Optim v1.7.5
#   [7f7a1694] Optimization v3.14.1
#   [253f991c] OptimizationFlux v0.1.4
#   [91a5bcdd] Plots v1.38.11
#   [438e738f] PyCall v1.95.1
#   [d330b81b] PyPlot v2.11.1
#   [731186ca] RecursiveArrayTools v2.38.3
#   [1ed8b502] SciMLSensitivity v7.31.0
#   [e88e6eb3] Zygote v0.6.61

# %%
using DiffEqFlux
using SciMLSensitivity
using Optimization
using DifferentialEquations.StochasticDiffEq
using DifferentialEquations.DiffEqCallbacks
using DifferentialEquations.DiffEqNoiseProcess
using Statistics, LinearAlgebra, Random
using Plots
using DifferentialEquations.DiffEqBase.EnsembleAnalysis
using BenchmarkTools
using LaTeXStrings
using Printf # print formatting
using ForwardDiff
using Graphs
using GraphRecipes
using RecursiveArrayTools
using Lux

# %%
# set up problem: initial conditions, params, solver hyperparams
datasize = 201
tspan = (0.0, 10.0)
tsteps = range(tspan[1], tspan[2], length = datasize)
NOISE_STRUCT = zeros(Float64,2,4)
u_0 = Float64[
    100.0,
    0.0
]

# produce NN for rates expressions in drift and diffusion functions of SDE
function ratestodrift(u, p, t)
    R1,R2,R3,R4 = ratesmodel(u,rebuild(p),st)[1]
    return [
        R4-(R1+R3),
        R3-(R2+R4)
    ]
end

function ratestodiff(u, p, t)
    R1_r,R2_r,R3_r,R4_r = ratesmodel(u,rebuild(p),st)[1].^(1/2)
    return [
        R1_r 0.0 -R3_r R4_r;
        0.0 R2_r R3_r R4_r
    ]
end

# generate feedforward NN
ratesmodel = Lux.Chain(Lux.Dense(2, 16, relu), Lux.Dense(16, 4, relu));
p_nn, st = Lux.setup(Xoshiro(0), ratesmodel)

# can destructure params and Restructure them out of p_nn
flat, rebuild = Flux.destructure(p_nn)
rebuild(flat)

# reflecting condition, helps stabilize ensemble results
# see https://stackoverflow.com/questions/69049991/simulating-a-reflecting-boundary-sdeproblem
function affect!(integrator)
    if integrator.u[2] < 0
        integrator.u[2] = -integrator.u[2]
    end
end
condition(u,t,integrator) = true
cb_reflect = DiscreteCallback(condition,affect!;save_positions=(false,false))
cbs = CallbackSet(cb_reflect)

# need to implement functions to recover parameters from Lux structures
prob = SDEProblem(
    ratestodrift,
    ratestodiff,
    u_0,
    tspan,
    Flux.destructure(p_nn)[1],
    noise_rate_prototype = NOISE_STRUCT,
    callback=cbs
)

sol = solve(prob, EM(), dt=0.05, saveat=0.05; sensealg=TrackerAdjoint(), save_everystep=false)
plot(sol.t, Array(sol)')

# %%
function loss_neuralsde(p,u=u_0)
    dt = 0.05
    prob = SDEProblem(ratestodrift, ratestodiff, u, tspan, p, noise_rate_prototype = NOISE_STRUCT, callback=cbs)
    sol = solve(prob, EM(), dt = dt, saveat = dt; save_everystep=false, sensealg=InterpolatingAdjoint(autojacvec = SciMLSensitivity.ReverseDiffVJP(), noisemixing = true)) #BacksolveAdjoint(autojacvec = SciMLSensitivity.ReverseDiffVJP(), noisemixing = true))
    loss = sum(abs2,sol[:,:])
    return loss, sol
end

res = Zygote.gradient(p->loss_neuralsde(p,u_0)[1],flat)[1]
# Out:
# BoundsError: attempt to access 385-element Vector{Float64} at index [386]
#
# Stacktrace:
#   [1] getindex
#     @ ./array.jl:861 [inlined]
#   [2] get_tprev
#     @ ~/.julia/packages/SciMLSensitivity/E8w3Z/src/callback_tracking.jl:499 [inlined]
#   [3] (::SciMLSensitivity.var"#affect!#241"{DiscreteCallback{typeof(condition), SciMLSensitivity.TrackedAffect{Float64, Vector{Float64}, Vector{Float32}, typeof(affect!), Nothing, Int64}, typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}, InterpolatingAdjoint{0, true, Val{:central}, ReverseDiffVJP{false}}, SciMLSensitivity.var"#df_iip#284"{Matrix{Float64}, Colon}, Nothing, Dict{Tuple{Bool, Nothing}, Tuple{SciMLSensitivity.AdjointDiffCache{Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, ReverseDiff.GradientTape{SciMLSensitivity.var"#127#131"{SciMLSensitivity.var"#242#244"{DiscreteCallback{typeof(condition), SciMLSensitivity.TrackedAffect{Float64, Vector{Float64}, Vector{Float32}, typeof(affect!), Nothing, Int64}, typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}, ReverseDiffVJP{false}, Float64, Bool}}, Tuple{ReverseDiff.TrackedArray{Float64, Float64, 1, Vector{Float64}, Vector{Float64}}, ReverseDiff.TrackedArray{Float32, Float64, 1, Vector{Float32}, Vector{Float64}}, ReverseDiff.TrackedArray{Float64, Float64, 1, Vector{Float64}, Vector{Float64}}}, Vector{ReverseDiff.TrackedReal{Float32, Float64, ReverseDiff.TrackedArray{Float32, Float64, 1, Vector{Float32}, Vector{Float64}}}}}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing}, SciMLSensitivity.AdjointDiffCache{Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, ReverseDiff.GradientTape{SciMLSensitivity.var"#127#131"{SciMLSensitivity.var"#243#245"{DiscreteCallback{typeof(condition), SciMLSensitivity.TrackedAffect{Float64, Vector{Float64}, Vector{Float32}, typeof(affect!), Nothing, Int64}, typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}, ReverseDiffVJP{false}, Float64, Bool}}, Tuple{ReverseDiff.TrackedArray{Float32, Float32, 1, Vector{Float32}, Vector{Float32}}, ReverseDiff.TrackedArray{Float64, Float32, 1, Vector{Float64}, Vector{Float32}}, ReverseDiff.TrackedArray{Float64, Float32, 1, Vector{Float64}, Vector{Float32}}}, Vector{ReverseDiff.TrackedReal{Float64, Float32, ReverseDiff.TrackedArray{Float64, Float32, 1, Vector{Float64}, Vector{Float32}}}}}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing}}}})(integrator::StochasticDiffEq.SDEIntegrator{EM{true}, true, Vector{Float64}, Float64, Float64, Float64, Vector{Float32}, Float64, Float64, Float64, NoiseWrapper{Float64, 2, Float64, Vector{Float64}, Nothing, NoiseProcess{Float64, 2, Float64, Vector{Float64}, Nothing, Nothing, typeof(DiffEqNoiseProcess.WHITE_NOISE_DIST), typeof(DiffEqNoiseProcess.WHITE_NOISE_BRIDGE), false, ResettableStacks.ResettableStack{Tuple{Float64, Vector{Float64}, Nothing}, false}, ResettableStacks.ResettableStack{Tuple{Float64, Vector{Float64}, Nothing}, false}, RSWM{Float64}, Nothing, RandomNumbers.Xorshifts.Xoroshiro128Plus}, Nothing, false}, Nothing, Vector{Float64}, RODESolution{Float64, 2, Vector{Vector{Float64}}, Nothing, Nothing, Vector{Float64}, NoiseWrapper{Float64, 2, Float64, Vector{Float64}, Nothing, NoiseProcess{Float64, 2, Float64, Vector{Float64}, Nothing, Nothing, typeof(DiffEqNoiseProcess.WHITE_NOISE_DIST), typeof(DiffEqNoiseProcess.WHITE_NOISE_BRIDGE), false, ResettableStacks.ResettableStack{Tuple{Float64, Vector{Float64}, Nothing}, false}, ResettableStacks.ResettableStack{Tuple{Float64, Vector{Float64}, Nothing}, false}, RSWM{Float64}, Nothing, RandomNumbers.Xorshifts.Xoroshiro128Plus}, Nothing, false}, SDEProblem{Vector{Float64}, Tuple{Float64, Float64}, true, Vector{Float32}, NoiseWrapper{Float64, 2, Float64, Vector{Float64}, Nothing, NoiseProcess{Float64, 2, Float64, Vector{Float64}, Nothing, Nothing, typeof(DiffEqNoiseProcess.WHITE_NOISE_DIST), typeof(DiffEqNoiseProcess.WHITE_NOISE_BRIDGE), false, ResettableStacks.ResettableStack{Tuple{Float64, Vector{Float64}, Nothing}, false}, ResettableStacks.ResettableStack{Tuple{Float64, Vector{Float64}, Nothing}, false}, RSWM{Float64}, Nothing, RandomNumbers.Xorshifts.Xoroshiro128Plus ...
#     @ SciMLSensitivity ~/.julia/packages/SciMLSensitivity/E8w3Z/src/callback_tracking.jl:250
#   [4] (::DiffEqCallbacks.var"#62#65"{typeof(SciMLBase.INITIALIZE_DEFAULT), Bool, Vector{Float64}, SciMLSensitivity.var"#affect!#241"{DiscreteCallback{typeof(condition), SciMLSensitivity.TrackedAffect{Float64, Vector{Float64}, Vector{Float32}, typeof(affect!), Nothing, Int64}, typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}, InterpolatingAdjoint{0, true, Val{:central}, ReverseDiffVJP{false}}, SciMLSensitivity.var"#df_iip#284"{Matrix{Float64}, Colon}, Nothing, Dict{Tuple{Bool, Nothing}, Tuple{SciMLSensitivity.AdjointDiffCache{Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, ReverseDiff.GradientTape{SciMLSensitivity.var"#127#131"{SciMLSensitivity.var"#242#244"{DiscreteCallback{typeof(condition), SciMLSensitivity.TrackedAffect{Float64, Vector{Float64}, Vector{Float32}, typeof(affect!), Nothing, Int64}, typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}, ReverseDiffVJP{false}, Float64, Bool}}, Tuple{ReverseDiff.TrackedArray{Float64, Float64, 1, Vector{Float64}, Vector{Float64}}, ReverseDiff.TrackedArray{Float32, Float64, 1, Vector{Float32}, Vector{Float64}}, ReverseDiff.TrackedArray{Float64, Float64, 1, Vector{Float64}, Vector{Float64}}}, Vector{ReverseDiff.TrackedReal{Float32, Float64, ReverseDiff.TrackedArray{Float32, Float64, 1, Vector{Float32}, Vector{Float64}}}}}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing}, SciMLSensitivity.AdjointDiffCache{Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, ReverseDiff.GradientTape{SciMLSensitivity.var"#127#131"{SciMLSensitivity.var"#243#245"{DiscreteCallback{typeof(condition), SciMLSensitivity.TrackedAffect{Float64, Vector{Float64}, Vector{Float32}, typeof(affect!), Nothing, Int64}, typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}, ReverseDiffVJP{false}, Float64, Bool}}, Tuple{ReverseDiff.TrackedArray{Float32, Float32, 1, Vector{Float32}, Vector{Float32}}, ReverseDiff.TrackedArray{Float64, Float32, 1, Vector{Float64}, Vector{Float32}}, ReverseDiff.TrackedArray{Float64, Float32, 1, Vector{Float64}, Vector{Float32}}}, Vector{ReverseDiff.TrackedReal{Float64, Float32, ReverseDiff.TrackedArray{Float64, Float32, 1, Vector{Float64}, Vector{Float32}}}}}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing}}}}})(c::DiscreteCallback{DiffEqCallbacks.var"#60#63"{Vector{Float64}}, DiffEqCallbacks.var"#61#64"{SciMLSensitivity.var"#affect!#241"{DiscreteCallback{typeof(condition), SciMLSensitivity.TrackedAffect{Float64, Vector{Float64}, Vector{Float32}, typeof(affect!), Nothing, Int64}, typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}, InterpolatingAdjoint{0, true, Val{:central}, ReverseDiffVJP{false}}, SciMLSensitivity.var"#df_iip#284"{Matrix{Float64}, Colon}, Nothing, Dict{Tuple{Bool, Nothing}, Tuple{SciMLSensitivity.AdjointDiffCache{Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, ReverseDiff.GradientTape{SciMLSensitivity.var"#127#131"{SciMLSensitivity.var"#242#244"{DiscreteCallback{typeof(condition), SciMLSensitivity.TrackedAffect{Float64, Vector{Float64}, Vector{Float32}, typeof(affect!), Nothing, Int64}, typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}, ReverseDiffVJP{false}, Float64, Bool}}, Tuple{ReverseDiff.TrackedArray{Float64, Float64, 1, Vector{Float64}, Vector{Float64}}, ReverseDiff.TrackedArray{Float32, Float64, 1, Vector{Float32}, Vector{Float64}}, ReverseDiff.TrackedArray{Float64, Float64, 1, Vector{Float64}, Vector{Float64}}}, Vector{ReverseDiff.TrackedReal{Float32, Float64, ReverseDiff.TrackedArray{Float32, Float64, 1, Vector{Float32}, Vector{Float64}}}}}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing}, SciMLSensitivity.AdjointDiffCache{Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, ReverseDiff.GradientTape{SciMLSensitivity.var"#127#131"{SciMLSensitivity.var"#243#245"{DiscreteCallback{typeof(condition), Sci ...
#     @ DiffEqCallbacks ~/.julia/packages/DiffEqCallbacks/il04Z/src/preset_time.jl:50
#   [5] initialize!
#     @ ~/.julia/packages/DiffEqBase/ZXMKG/src/callbacks.jl:18 [inlined]
#   [6] initialize!
#     @ ~/.julia/packages/DiffEqBase/ZXMKG/src/callbacks.jl:14 [inlined]
#   [7] initialize!
#     @ ~/.julia/packages/DiffEqBase/ZXMKG/src/callbacks.jl:7 [inlined]
#   [8] initialize_callbacks!(integrator::StochasticDiffEq.SDEIntegrator{EM{true}, true, Vector{Float64}, Float64, Float64, Float64, Vector{Float32}, Float64, Float64, Float64, NoiseWrapper{Float64, 2, Float64, Vector{Float64}, Nothing, NoiseProcess{Float64, 2, Float64, Vector{Float64}, Nothing, Nothing, typeof(DiffEqNoiseProcess.WHITE_NOISE_DIST), typeof(DiffEqNoiseProcess.WHITE_NOISE_BRIDGE), false, ResettableStacks.ResettableStack{Tuple{Float64, Vector{Float64}, Nothing}, false}, ResettableStacks.ResettableStack{Tuple{Float64, Vector{Float64}, Nothing}, false}, RSWM{Float64}, Nothing, RandomNumbers.Xorshifts.Xoroshiro128Plus}, Nothing, false}, Nothing, Vector{Float64}, RODESolution{Float64, 2, Vector{Vector{Float64}}, Nothing, Nothing, Vector{Float64}, NoiseWrapper{Float64, 2, Float64, Vector{Float64}, Nothing, NoiseProcess{Float64, 2, Float64, Vector{Float64}, Nothing, Nothing, typeof(DiffEqNoiseProcess.WHITE_NOISE_DIST), typeof(DiffEqNoiseProcess.WHITE_NOISE_BRIDGE), false, ResettableStacks.ResettableStack{Tuple{Float64, Vector{Float64}, Nothing}, false}, ResettableStacks.ResettableStack{Tuple{Float64, Vector{Float64}, Nothing}, false}, RSWM{Float64}, Nothing, RandomNumbers.Xorshifts.Xoroshiro128Plus}, Nothing, false}, SDEProblem{Vector{Float64}, Tuple{Float64, Float64}, true, Vector{Float32}, NoiseWrapper{Float64, 2, Float64, Vector{Float64}, Nothing, NoiseProcess{Float64, 2, Float64, Vector{Float64}, Nothing, Nothing, typeof(DiffEqNoiseProcess.WHITE_NOISE_DIST), typeof(DiffEqNoiseProcess.WHITE_NOISE_BRIDGE), false, ResettableStacks.ResettableStack{Tuple{Float64, Vector{Float64}, Nothing}, false}, ResettableStacks.ResettableStack{Tuple{Float64, Vector{Float64}, Nothing}, false}, RSWM{Float64}, Nothing, RandomNumbers.Xorshifts.Xoroshiro128Plus}, Nothing, false}, SDEFunction{true, SciMLBase.FullSpecialize, SciMLSensitivity.ODEInterpolatingAdjointSensitivityFunction{SciMLSensitivity.AdjointDiffCache{Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, ReverseDiff.GradientTape{SciMLSensitivity.var"#129#133"{SDEFunction{false, SciMLBase.FullSpecialize, typeof(ratestodrift), typeof(ratestodiff), UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing}}, Tuple{ReverseDiff.TrackedArray{Float64, Float64, 1, Vector{Float64}, Vector{Float64}}, ReverseDiff.TrackedArray{Float32, Float64, 1, Vector{Float32}, Vector{Float64}}, ReverseDiff.TrackedArray{Float64, Float64, 1, Vector{Float64}, Vector{Float64}}}, Vector{ReverseDiff.TrackedReal{Float64, Float64, Nothing}}}, Nothing, Nothing, Nothing, Nothing, Nothing, Base.OneTo{Int64}, UnitRange{Int64}, UniformScaling{Bool}}, InterpolatingAdjoint{0, true, Val{:central}, ReverseDiffVJP{false}}, Vector{Float64}, RODESolution{Float64, 2, Vector{Vector{Float64}}, Nothing, Nothing, Vector{Float64}, NoiseProcess{Float64, 2, Float64, Vector{Float64}, Nothing, Nothing, typeof(DiffEqNoiseProcess.WHITE_NOISE_DIST), typeof(DiffEqNoiseProcess.WHITE_NOISE_BRIDGE), false, ResettableStacks.ResettableStack{Tuple{Float64, Vector{Float64}, Nothing}, false}, ResettableStacks.ResettableStack{Tuple{Float64, Vector{Float64}, Nothing}, false}, RSWM{Float64}, Nothing, RandomNumbers.Xorshifts.Xoroshiro128Plus}, SDEProblem{Vector{Float64}, Tuple{Float64, Float64}, false, Vector{Float32}, Nothing, SDEFunction{false, SciMLBase.FullSpecialize, typeof(ratestodrift), typeof(ratestodiff), UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing}, typeof(ratestodiff), Base.Pairs{Symbol, CallbackSet{Tuple{}, Tuple{DiscreteCallback{typeof(condition), SciMLSensitivity.TrackedAffect{Float64, Vector{Float64}, Vector{Float32}, typeof(affect!), Nothing, Int64}, typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAUL ...
#     @ StochasticDiffEq ~/.julia/packages/StochasticDiffEq/rZj4R/src/solve.jl:658
#   [9] __init(_prob::SDEProblem{Vector{Float64}, Tuple{Float64, Float64}, true, Vector{Float32}, NoiseWrapper{Float64, 2, Float64, Vector{Float64}, Nothing, NoiseProcess{Float64, 2, Float64, Vector{Float64}, Nothing, Nothing, typeof(DiffEqNoiseProcess.WHITE_NOISE_DIST), typeof(DiffEqNoiseProcess.WHITE_NOISE_BRIDGE), false, ResettableStacks.ResettableStack{Tuple{Float64, Vector{Float64}, Nothing}, false}, ResettableStacks.ResettableStack{Tuple{Float64, Vector{Float64}, Nothing}, false}, RSWM{Float64}, Nothing, RandomNumbers.Xorshifts.Xoroshiro128Plus}, Nothing, false}, SDEFunction{true, SciMLBase.FullSpecialize, SciMLSensitivity.ODEInterpolatingAdjointSensitivityFunction{SciMLSensitivity.AdjointDiffCache{Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, ReverseDiff.GradientTape{SciMLSensitivity.var"#129#133"{SDEFunction{false, SciMLBase.FullSpecialize, typeof(ratestodrift), typeof(ratestodiff), UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing}}, Tuple{ReverseDiff.TrackedArray{Float64, Float64, 1, Vector{Float64}, Vector{Float64}}, ReverseDiff.TrackedArray{Float32, Float64, 1, Vector{Float32}, Vector{Float64}}, ReverseDiff.TrackedArray{Float64, Float64, 1, Vector{Float64}, Vector{Float64}}}, Vector{ReverseDiff.TrackedReal{Float64, Float64, Nothing}}}, Nothing, Nothing, Nothing, Nothing, Nothing, Base.OneTo{Int64}, UnitRange{Int64}, UniformScaling{Bool}}, InterpolatingAdjoint{0, true, Val{:central}, ReverseDiffVJP{false}}, Vector{Float64}, RODESolution{Float64, 2, Vector{Vector{Float64}}, Nothing, Nothing, Vector{Float64}, NoiseProcess{Float64, 2, Float64, Vector{Float64}, Nothing, Nothing, typeof(DiffEqNoiseProcess.WHITE_NOISE_DIST), typeof(DiffEqNoiseProcess.WHITE_NOISE_BRIDGE), false, ResettableStacks.ResettableStack{Tuple{Float64, Vector{Float64}, Nothing}, false}, ResettableStacks.ResettableStack{Tuple{Float64, Vector{Float64}, Nothing}, false}, RSWM{Float64}, Nothing, RandomNumbers.Xorshifts.Xoroshiro128Plus}, SDEProblem{Vector{Float64}, Tuple{Float64, Float64}, false, Vector{Float32}, Nothing, SDEFunction{false, SciMLBase.FullSpecialize, typeof(ratestodrift), typeof(ratestodiff), UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing}, typeof(ratestodiff), Base.Pairs{Symbol, CallbackSet{Tuple{}, Tuple{DiscreteCallback{typeof(condition), SciMLSensitivity.TrackedAffect{Float64, Vector{Float64}, Vector{Float32}, typeof(affect!), Nothing, Int64}, typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}}}, Tuple{Symbol}, NamedTuple{(:callback,), Tuple{CallbackSet{Tuple{}, Tuple{DiscreteCallback{typeof(condition), SciMLSensitivity.TrackedAffect{Float64, Vector{Float64}, Vector{Float32}, typeof(affect!), Nothing, Int64}, typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}}}}}}, Matrix{Float64}}, EM{true}, StochasticDiffEq.LinearInterpolationData{Vector{Vector{Float64}}, Vector{Float64}}, DiffEqBase.Stats, Nothing}, SciMLSensitivity.CheckpointSolution{RODESolution{Float64, 2, Vector{Vector{Float64}}, Nothing, Nothing, Vector{Float64}, NoiseWrapper{Float64, 2, Float64, Vector{Float64}, Nothing, NoiseProcess{Float64, 2, Float64, Vector{Float64}, Nothing, Nothing, typeof(DiffEqNoiseProcess.WHITE_NOISE_DIST), typeof(DiffEqNoiseProcess.WHITE_NOISE_BRIDGE), false, ResettableStacks.ResettableStack{Tuple{Float64, Vector{Float64}, Nothing}, false}, ResettableStacks.ResettableStack{Tuple{Float64, Vector{Float64}, Nothing}, false}, RSWM{Float64}, Nothing, RandomNumbers.Xorshifts.Xoroshiro128Plus}, Nothing, false}, SDEProblem{Vector{Float64}, Tuple{Float64, Float64}, false, Vector{Float32}, NoiseWrapper{Float64, 2, Float64, Vector{Float64}, Nothing, NoiseProcess{Float64, 2, Float64, Vector{F ...
#     @ StochasticDiffEq ~/.julia/packages/StochasticDiffEq/rZj4R/src/solve.jl:585
#  [10] __solve(prob::SDEProblem{Vector{Float64}, Tuple{Float64, Float64}, true, Vector{Float32}, NoiseWrapper{Float64, 2, Float64, Vector{Float64}, Nothing, NoiseProcess{Float64, 2, Float64, Vector{Float64}, Nothing, Nothing, typeof(DiffEqNoiseProcess.WHITE_NOISE_DIST), typeof(DiffEqNoiseProcess.WHITE_NOISE_BRIDGE), false, ResettableStacks.ResettableStack{Tuple{Float64, Vector{Float64}, Nothing}, false}, ResettableStacks.ResettableStack{Tuple{Float64, Vector{Float64}, Nothing}, false}, RSWM{Float64}, Nothing, RandomNumbers.Xorshifts.Xoroshiro128Plus}, Nothing, false}, SDEFunction{true, SciMLBase.FullSpecialize, SciMLSensitivity.ODEInterpolatingAdjointSensitivityFunction{SciMLSensitivity.AdjointDiffCache{Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, ReverseDiff.GradientTape{SciMLSensitivity.var"#129#133"{SDEFunction{false, SciMLBase.FullSpecialize, typeof(ratestodrift), typeof(ratestodiff), UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing}}, Tuple{ReverseDiff.TrackedArray{Float64, Float64, 1, Vector{Float64}, Vector{Float64}}, ReverseDiff.TrackedArray{Float32, Float64, 1, Vector{Float32}, Vector{Float64}}, ReverseDiff.TrackedArray{Float64, Float64, 1, Vector{Float64}, Vector{Float64}}}, Vector{ReverseDiff.TrackedReal{Float64, Float64, Nothing}}}, Nothing, Nothing, Nothing, Nothing, Nothing, Base.OneTo{Int64}, UnitRange{Int64}, UniformScaling{Bool}}, InterpolatingAdjoint{0, true, Val{:central}, ReverseDiffVJP{false}}, Vector{Float64}, RODESolution{Float64, 2, Vector{Vector{Float64}}, Nothing, Nothing, Vector{Float64}, NoiseProcess{Float64, 2, Float64, Vector{Float64}, Nothing, Nothing, typeof(DiffEqNoiseProcess.WHITE_NOISE_DIST), typeof(DiffEqNoiseProcess.WHITE_NOISE_BRIDGE), false, ResettableStacks.ResettableStack{Tuple{Float64, Vector{Float64}, Nothing}, false}, ResettableStacks.ResettableStack{Tuple{Float64, Vector{Float64}, Nothing}, false}, RSWM{Float64}, Nothing, RandomNumbers.Xorshifts.Xoroshiro128Plus}, SDEProblem{Vector{Float64}, Tuple{Float64, Float64}, false, Vector{Float32}, Nothing, SDEFunction{false, SciMLBase.FullSpecialize, typeof(ratestodrift), typeof(ratestodiff), UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing}, typeof(ratestodiff), Base.Pairs{Symbol, CallbackSet{Tuple{}, Tuple{DiscreteCallback{typeof(condition), SciMLSensitivity.TrackedAffect{Float64, Vector{Float64}, Vector{Float32}, typeof(affect!), Nothing, Int64}, typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}}}, Tuple{Symbol}, NamedTuple{(:callback,), Tuple{CallbackSet{Tuple{}, Tuple{DiscreteCallback{typeof(condition), SciMLSensitivity.TrackedAffect{Float64, Vector{Float64}, Vector{Float32}, typeof(affect!), Nothing, Int64}, typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}}}}}}, Matrix{Float64}}, EM{true}, StochasticDiffEq.LinearInterpolationData{Vector{Vector{Float64}}, Vector{Float64}}, DiffEqBase.Stats, Nothing}, SciMLSensitivity.CheckpointSolution{RODESolution{Float64, 2, Vector{Vector{Float64}}, Nothing, Nothing, Vector{Float64}, NoiseWrapper{Float64, 2, Float64, Vector{Float64}, Nothing, NoiseProcess{Float64, 2, Float64, Vector{Float64}, Nothing, Nothing, typeof(DiffEqNoiseProcess.WHITE_NOISE_DIST), typeof(DiffEqNoiseProcess.WHITE_NOISE_BRIDGE), false, ResettableStacks.ResettableStack{Tuple{Float64, Vector{Float64}, Nothing}, false}, ResettableStacks.ResettableStack{Tuple{Float64, Vector{Float64}, Nothing}, false}, RSWM{Float64}, Nothing, RandomNumbers.Xorshifts.Xoroshiro128Plus}, Nothing, false}, SDEProblem{Vector{Float64}, Tuple{Float64, Float64}, false, Vector{Float32}, NoiseWrapper{Float64, 2, Float64, Vector{Float64}, Nothing, NoiseProcess{Float64, 2, Float64, Vector{F ...
#     @ StochasticDiffEq ~/.julia/packages/StochasticDiffEq/rZj4R/src/solve.jl:6
#  [11] solve_call(_prob::SDEProblem{Vector{Float64}, Tuple{Float64, Float64}, true, Vector{Float32}, NoiseWrapper{Float64, 2, Float64, Vector{Float64}, Nothing, NoiseProcess{Float64, 2, Float64, Vector{Float64}, Nothing, Nothing, typeof(DiffEqNoiseProcess.WHITE_NOISE_DIST), typeof(DiffEqNoiseProcess.WHITE_NOISE_BRIDGE), false, ResettableStacks.ResettableStack{Tuple{Float64, Vector{Float64}, Nothing}, false}, ResettableStacks.ResettableStack{Tuple{Float64, Vector{Float64}, Nothing}, false}, RSWM{Float64}, Nothing, RandomNumbers.Xorshifts.Xoroshiro128Plus}, Nothing, false}, SDEFunction{true, SciMLBase.FullSpecialize, SciMLSensitivity.ODEInterpolatingAdjointSensitivityFunction{SciMLSensitivity.AdjointDiffCache{Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, ReverseDiff.GradientTape{SciMLSensitivity.var"#129#133"{SDEFunction{false, SciMLBase.FullSpecialize, typeof(ratestodrift), typeof(ratestodiff), UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing}}, Tuple{ReverseDiff.TrackedArray{Float64, Float64, 1, Vector{Float64}, Vector{Float64}}, ReverseDiff.TrackedArray{Float32, Float64, 1, Vector{Float32}, Vector{Float64}}, ReverseDiff.TrackedArray{Float64, Float64, 1, Vector{Float64}, Vector{Float64}}}, Vector{ReverseDiff.TrackedReal{Float64, Float64, Nothing}}}, Nothing, Nothing, Nothing, Nothing, Nothing, Base.OneTo{Int64}, UnitRange{Int64}, UniformScaling{Bool}}, InterpolatingAdjoint{0, true, Val{:central}, ReverseDiffVJP{false}}, Vector{Float64}, RODESolution{Float64, 2, Vector{Vector{Float64}}, Nothing, Nothing, Vector{Float64}, NoiseProcess{Float64, 2, Float64, Vector{Float64}, Nothing, Nothing, typeof(DiffEqNoiseProcess.WHITE_NOISE_DIST), typeof(DiffEqNoiseProcess.WHITE_NOISE_BRIDGE), false, ResettableStacks.ResettableStack{Tuple{Float64, Vector{Float64}, Nothing}, false}, ResettableStacks.ResettableStack{Tuple{Float64, Vector{Float64}, Nothing}, false}, RSWM{Float64}, Nothing, RandomNumbers.Xorshifts.Xoroshiro128Plus}, SDEProblem{Vector{Float64}, Tuple{Float64, Float64}, false, Vector{Float32}, Nothing, SDEFunction{false, SciMLBase.FullSpecialize, typeof(ratestodrift), typeof(ratestodiff), UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing}, typeof(ratestodiff), Base.Pairs{Symbol, CallbackSet{Tuple{}, Tuple{DiscreteCallback{typeof(condition), SciMLSensitivity.TrackedAffect{Float64, Vector{Float64}, Vector{Float32}, typeof(affect!), Nothing, Int64}, typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}}}, Tuple{Symbol}, NamedTuple{(:callback,), Tuple{CallbackSet{Tuple{}, Tuple{DiscreteCallback{typeof(condition), SciMLSensitivity.TrackedAffect{Float64, Vector{Float64}, Vector{Float32}, typeof(affect!), Nothing, Int64}, typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}}}}}}, Matrix{Float64}}, EM{true}, StochasticDiffEq.LinearInterpolationData{Vector{Vector{Float64}}, Vector{Float64}}, DiffEqBase.Stats, Nothing}, SciMLSensitivity.CheckpointSolution{RODESolution{Float64, 2, Vector{Vector{Float64}}, Nothing, Nothing, Vector{Float64}, NoiseWrapper{Float64, 2, Float64, Vector{Float64}, Nothing, NoiseProcess{Float64, 2, Float64, Vector{Float64}, Nothing, Nothing, typeof(DiffEqNoiseProcess.WHITE_NOISE_DIST), typeof(DiffEqNoiseProcess.WHITE_NOISE_BRIDGE), false, ResettableStacks.ResettableStack{Tuple{Float64, Vector{Float64}, Nothing}, false}, ResettableStacks.ResettableStack{Tuple{Float64, Vector{Float64}, Nothing}, false}, RSWM{Float64}, Nothing, RandomNumbers.Xorshifts.Xoroshiro128Plus}, Nothing, false}, SDEProblem{Vector{Float64}, Tuple{Float64, Float64}, false, Vector{Float32}, NoiseWrapper{Float64, 2, Float64, Vector{Float64}, Nothing, NoiseProcess{Float64, 2, Float64, Vect ...
#     @ DiffEqBase ~/.julia/packages/DiffEqBase/ZXMKG/src/solve.jl:511
#  [12] #solve_up#30
#     @ ~/.julia/packages/DiffEqBase/ZXMKG/src/solve.jl:971 [inlined]
#  [13] #solve#28
#     @ ~/.julia/packages/DiffEqBase/ZXMKG/src/solve.jl:881 [inlined]
#  [14] _adjoint_sensitivities(sol::RODESolution{Float64, 2, Vector{Vector{Float64}}, Nothing, Nothing, Vector{Float64}, NoiseProcess{Float64, 2, Float64, Vector{Float64}, Nothing, Nothing, typeof(DiffEqNoiseProcess.WHITE_NOISE_DIST), typeof(DiffEqNoiseProcess.WHITE_NOISE_BRIDGE), false, ResettableStacks.ResettableStack{Tuple{Float64, Vector{Float64}, Nothing}, false}, ResettableStacks.ResettableStack{Tuple{Float64, Vector{Float64}, Nothing}, false}, RSWM{Float64}, Nothing, RandomNumbers.Xorshifts.Xoroshiro128Plus}, SDEProblem{Vector{Float64}, Tuple{Float64, Float64}, false, Vector{Float32}, Nothing, SDEFunction{false, SciMLBase.FullSpecialize, typeof(ratestodrift), typeof(ratestodiff), UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing}, typeof(ratestodiff), Base.Pairs{Symbol, CallbackSet{Tuple{}, Tuple{DiscreteCallback{typeof(condition), SciMLSensitivity.TrackedAffect{Float64, Vector{Float64}, Vector{Float32}, typeof(affect!), Nothing, Int64}, typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}}}, Tuple{Symbol}, NamedTuple{(:callback,), Tuple{CallbackSet{Tuple{}, Tuple{DiscreteCallback{typeof(condition), SciMLSensitivity.TrackedAffect{Float64, Vector{Float64}, Vector{Float32}, typeof(affect!), Nothing, Int64}, typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}}}}}}, Matrix{Float64}}, EM{true}, StochasticDiffEq.LinearInterpolationData{Vector{Vector{Float64}}, Vector{Float64}}, DiffEqBase.Stats, Nothing}, sensealg::InterpolatingAdjoint{0, true, Val{:central}, ReverseDiffVJP{false}}, alg::EM{true}; t::StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, dgdu_discrete::Function, dgdp_discrete::Nothing, dgdu_continuous::Nothing, dgdp_continuous::Nothing, g::Nothing, abstol::Float64, reltol::Float64, checkpoints::Vector{Float64}, corfunc_analytical::Nothing, callback::CallbackSet{Tuple{}, Tuple{DiscreteCallback{typeof(condition), SciMLSensitivity.TrackedAffect{Float64, Vector{Float64}, Vector{Float32}, typeof(affect!), Nothing, Int64}, typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}}}, kwargs::Base.Pairs{Symbol, Real, Tuple{Symbol, Symbol, Symbol}, NamedTuple{(:verbose, :dt, :save_everystep), Tuple{Bool, Float64, Bool}}})
#     @ SciMLSensitivity ~/.julia/packages/SciMLSensitivity/E8w3Z/src/sensitivity_interface.jl:433
#  [15] #adjoint_sensitivities#67
#     @ ~/.julia/packages/SciMLSensitivity/E8w3Z/src/sensitivity_interface.jl:386 [inlined]
#  [16] (::SciMLSensitivity.var"#adjoint_sensitivity_backpass#283"{Base.Pairs{Symbol, Any, Tuple{Symbol, Symbol, Symbol}, NamedTuple{(:callback, :dt, :save_everystep), Tuple{CallbackSet{Tuple{}, Tuple{DiscreteCallback{typeof(condition), typeof(affect!), typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}}}, Float64, Bool}}}, EM{true}, InterpolatingAdjoint{0, true, Val{:central}, ReverseDiffVJP{false}}, Vector{Float64}, Vector{Float32}, SciMLBase.ChainRulesOriginator, Tuple{}, Colon, NamedTuple{(:dt, :save_everystep), Tuple{Float64, Bool}}})(Δ::Matrix{Float64})
#     @ SciMLSensitivity ~/.julia/packages/SciMLSensitivity/E8w3Z/src/concrete_solve.jl:523
#  [17] ZBack
#     @ ~/.julia/packages/Zygote/HTsWj/src/compiler/chainrules.jl:211 [inlined]
#  [18] (::Zygote.var"#kw_zpullback#53"{SciMLSensitivity.var"#adjoint_sensitivity_backpass#283"{Base.Pairs{Symbol, Any, Tuple{Symbol, Symbol, Symbol}, NamedTuple{(:callback, :dt, :save_everystep), Tuple{CallbackSet{Tuple{}, Tuple{DiscreteCallback{typeof(condition), typeof(affect!), typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}}}, Float64, Bool}}}, EM{true}, InterpolatingAdjoint{0, true, Val{:central}, ReverseDiffVJP{false}}, Vector{Float64}, Vector{Float32}, SciMLBase.ChainRulesOriginator, Tuple{}, Colon, NamedTuple{(:dt, :save_everystep), Tuple{Float64, Bool}}}})(dy::Matrix{Float64})
#     @ Zygote ~/.julia/packages/Zygote/HTsWj/src/compiler/chainrules.jl:237
#  [19] #287
#     @ ~/.julia/packages/Zygote/HTsWj/src/lib/lib.jl:206 [inlined]
#  [20] (::Zygote.var"#2139#back#289"{Zygote.var"#287#288"{Tuple{NTuple{6, Nothing}, Tuple{Nothing}}, Zygote.var"#kw_zpullback#53"{SciMLSensitivity.var"#adjoint_sensitivity_backpass#283"{Base.Pairs{Symbol, Any, Tuple{Symbol, Symbol, Symbol}, NamedTuple{(:callback, :dt, :save_everystep), Tuple{CallbackSet{Tuple{}, Tuple{DiscreteCallback{typeof(condition), typeof(affect!), typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}}}, Float64, Bool}}}, EM{true}, InterpolatingAdjoint{0, true, Val{:central}, ReverseDiffVJP{false}}, Vector{Float64}, Vector{Float32}, SciMLBase.ChainRulesOriginator, Tuple{}, Colon, NamedTuple{(:dt, :save_everystep), Tuple{Float64, Bool}}}}}})(Δ::Matrix{Float64})
#     @ Zygote ~/.julia/packages/ZygoteRules/OgCVT/src/adjoint.jl:71
#  [21] Pullback
#     @ ~/.julia/packages/DiffEqBase/ZXMKG/src/solve.jl:881 [inlined]
#  [22] (::Zygote.Pullback{Tuple{DiffEqBase.var"##solve#28", InterpolatingAdjoint{0, true, Val{:central}, ReverseDiffVJP{false}}, Nothing, Nothing, Val{true}, Base.Pairs{Symbol, Real, Tuple{Symbol, Symbol, Symbol}, NamedTuple{(:dt, :saveat, :save_everystep), Tuple{Float64, Float64, Bool}}}, typeof(solve), SDEProblem{Vector{Float64}, Tuple{Float64, Float64}, false, Vector{Float32}, Nothing, SDEFunction{false, SciMLBase.FullSpecialize, typeof(ratestodrift), typeof(ratestodiff), UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing}, typeof(ratestodiff), Base.Pairs{Symbol, CallbackSet{Tuple{}, Tuple{DiscreteCallback{typeof(condition), typeof(affect!), typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}}}, Tuple{Symbol}, NamedTuple{(:callback,), Tuple{CallbackSet{Tuple{}, Tuple{DiscreteCallback{typeof(condition), typeof(affect!), typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}}}}}}, Matrix{Float64}}, EM{true}}, Any})(Δ::Matrix{Float64})
#     @ Zygote ~/.julia/packages/Zygote/HTsWj/src/compiler/interface2.jl:0
#  [23] (::Zygote.var"#287#288"{Tuple{NTuple{7, Nothing}, Tuple{Nothing}}, Zygote.Pullback{Tuple{DiffEqBase.var"##solve#28", InterpolatingAdjoint{0, true, Val{:central}, ReverseDiffVJP{false}}, Nothing, Nothing, Val{true}, Base.Pairs{Symbol, Real, Tuple{Symbol, Symbol, Symbol}, NamedTuple{(:dt, :saveat, :save_everystep), Tuple{Float64, Float64, Bool}}}, typeof(solve), SDEProblem{Vector{Float64}, Tuple{Float64, Float64}, false, Vector{Float32}, Nothing, SDEFunction{false, SciMLBase.FullSpecialize, typeof(ratestodrift), typeof(ratestodiff), UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing}, typeof(ratestodiff), Base.Pairs{Symbol, CallbackSet{Tuple{}, Tuple{DiscreteCallback{typeof(condition), typeof(affect!), typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}}}, Tuple{Symbol}, NamedTuple{(:callback,), Tuple{CallbackSet{Tuple{}, Tuple{DiscreteCallback{typeof(condition), typeof(affect!), typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}}}}}}, Matrix{Float64}}, EM{true}}, Any}})(Δ::Matrix{Float64})
#     @ Zygote ~/.julia/packages/Zygote/HTsWj/src/lib/lib.jl:206
#  [24] (::Zygote.var"#2139#back#289"{Zygote.var"#287#288"{Tuple{NTuple{7, Nothing}, Tuple{Nothing}}, Zygote.Pullback{Tuple{DiffEqBase.var"##solve#28", InterpolatingAdjoint{0, true, Val{:central}, ReverseDiffVJP{false}}, Nothing, Nothing, Val{true}, Base.Pairs{Symbol, Real, Tuple{Symbol, Symbol, Symbol}, NamedTuple{(:dt, :saveat, :save_everystep), Tuple{Float64, Float64, Bool}}}, typeof(solve), SDEProblem{Vector{Float64}, Tuple{Float64, Float64}, false, Vector{Float32}, Nothing, SDEFunction{false, SciMLBase.FullSpecialize, typeof(ratestodrift), typeof(ratestodiff), UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing}, typeof(ratestodiff), Base.Pairs{Symbol, CallbackSet{Tuple{}, Tuple{DiscreteCallback{typeof(condition), typeof(affect!), typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}}}, Tuple{Symbol}, NamedTuple{(:callback,), Tuple{CallbackSet{Tuple{}, Tuple{DiscreteCallback{typeof(condition), typeof(affect!), typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}}}}}}, Matrix{Float64}}, EM{true}}, Any}}})(Δ::Matrix{Float64})
#     @ Zygote ~/.julia/packages/ZygoteRules/OgCVT/src/adjoint.jl:71
#  [25] Pullback
#     @ ~/.julia/packages/DiffEqBase/ZXMKG/src/solve.jl:873 [inlined]
#  [26] (::Zygote.Pullback{Tuple{CommonSolve.var"#solve##kw", NamedTuple{(:dt, :saveat, :save_everystep, :sensealg), Tuple{Float64, Float64, Bool, InterpolatingAdjoint{0, true, Val{:central}, ReverseDiffVJP{false}}}}, typeof(solve), SDEProblem{Vector{Float64}, Tuple{Float64, Float64}, false, Vector{Float32}, Nothing, SDEFunction{false, SciMLBase.FullSpecialize, typeof(ratestodrift), typeof(ratestodiff), UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing}, typeof(ratestodiff), Base.Pairs{Symbol, CallbackSet{Tuple{}, Tuple{DiscreteCallback{typeof(condition), typeof(affect!), typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}}}, Tuple{Symbol}, NamedTuple{(:callback,), Tuple{CallbackSet{Tuple{}, Tuple{DiscreteCallback{typeof(condition), typeof(affect!), typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}}}}}}, Matrix{Float64}}, EM{true}}, Any})(Δ::Matrix{Float64})
#     @ Zygote ~/.julia/packages/Zygote/HTsWj/src/compiler/interface2.jl:0
#  [27] Pullback
#     @ ./In[9]:4 [inlined]
#  [28] (::Zygote.Pullback{Tuple{typeof(loss_neuralsde), Vector{Float32}, Vector{Float64}}, Tuple{Zygote.var"#kw_zpullback#53"{DiffEqBase.var"#SDEProblemAdjoint#113"}, Zygote.var"#1956#back#190"{Zygote.var"#186#189"{Zygote.Context{false}, GlobalRef, Matrix{Float64}}}, Zygote.ZBack{ChainRules.var"#sum_abs2_pullback#1682"{Matrix{Float64}}}, Zygote.var"#2573#back#529"{Zygote.var"#539#541"{2, Float64, RODESolution{Float64, 2, Vector{Vector{Float64}}, Nothing, Nothing, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Nothing, SDEProblem{Vector{Float64}, Tuple{Float64, Float64}, false, Vector{Float32}, Nothing, SDEFunction{false, SciMLBase.FullSpecialize, typeof(ratestodrift), typeof(ratestodiff), UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing}, typeof(ratestodiff), Base.Pairs{Symbol, CallbackSet{Tuple{}, Tuple{DiscreteCallback{typeof(condition), SciMLSensitivity.TrackedAffect{Float64, Vector{Float64}, Vector{Float32}, typeof(affect!), Nothing, Int64}, typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}}}, Tuple{Symbol}, NamedTuple{(:callback,), Tuple{CallbackSet{Tuple{}, Tuple{DiscreteCallback{typeof(condition), SciMLSensitivity.TrackedAffect{Float64, Vector{Float64}, Vector{Float32}, typeof(affect!), Nothing, Int64}, typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}}}}}}, Matrix{Float64}}, EM{true}, StochasticDiffEq.LinearInterpolationData{Vector{Vector{Float64}}, Vector{Float64}}, DiffEqBase.Stats, Nothing}, Tuple{Colon, Colon}}}, Zygote.Pullback{Tuple{Type{NamedTuple{(:noise_rate_prototype, :callback)}}, Tuple{Matrix{Float64}, CallbackSet{Tuple{}, Tuple{DiscreteCallback{typeof(condition), typeof(affect!), typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}}}}}, Tuple{Zygote.Pullback{Tuple{Type{NamedTuple{(:noise_rate_prototype, :callback), Tuple{Matrix{Float64}, CallbackSet{Tuple{}, Tuple{DiscreteCallback{typeof(condition), typeof(affect!), typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}}}}}}, Tuple{Matrix{Float64}, CallbackSet{Tuple{}, Tuple{DiscreteCallback{typeof(condition), typeof(affect!), typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}}}}}, Tuple{Zygote.var"#2187#back#311"{Zygote.Jnew{NamedTuple{(:noise_rate_prototype, :callback), Tuple{Matrix{Float64}, CallbackSet{Tuple{}, Tuple{DiscreteCallback{typeof(condition), typeof(affect!), typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}}}}}, Nothing, true}}}}}}, Zygote.Pullback{Tuple{Type{NamedTuple{(:autojacvec, :noisemixing)}}, Tuple{ReverseDiffVJP{false}, Bool}}, Tuple{Zygote.Pullback{Tuple{Type{NamedTuple{(:autojacvec, :noisemixing), Tuple{ReverseDiffVJP{false}, Bool}}}, Tuple{ReverseDiffVJP{false}, Bool}}, Tuple{Zygote.var"#2187#back#311"{Zygote.Jnew{NamedTuple{(:autojacvec, :noisemixing), Tuple{ReverseDiffVJP{false}, Bool}}, Nothing, true}}}}}}, Zygote.Pullback{Tuple{Core.var"#Type##kw", NamedTuple{(:autojacvec, :noisemixing), Tuple{ReverseDiffVJP{false}, Bool}}, Type{InterpolatingAdjoint}}, Any}, Zygote.var"#1983#back#200"{typeof(identity)}, Zygote.Pullback{Tuple{Type{ReverseDiffVJP}}, Tuple{}}, Zygote.var"#1956#back#190"{Zygote.var"#186#189"{Zygote.Context{false}, GlobalRef, Tuple{Float64, Float64}}}, Zygote.var"#1983#back#200"{typeof(identity)}, Zygote.var"#1983#back#200"{typeof(identity)}, Zygote.var"#1956#back#190"{Zygote.var"#186#189"{Zygote.Context{false}, GlobalRef, CallbackSet{Tuple{}, Tuple{DiscreteCallback{typeof(condition), typeof(affect!), typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}}}}}, Zygote.Pullback{Tuple{CommonSolve.var"#solve##kw", NamedTuple{(:dt, :saveat, :save_everystep, :sensealg), Tuple{Float64, Float64, Bool, InterpolatingAdjoint{0, true, Val{:central}, ReverseDiffVJP{false}}}}, typeof(so ...
#     @ Zygote ~/.julia/packages/Zygote/HTsWj/src/compiler/interface2.jl:0
#  [29] Pullback
#     @ ./In[9]:9 [inlined]
#  [30] (::Zygote.Pullback{Tuple{var"#5#6", Vector{Float32}}, Tuple{Zygote.var"#1956#back#190"{Zygote.var"#186#189"{Zygote.Context{false}, GlobalRef, Vector{Float64}}}, Zygote.Pullback{Tuple{typeof(loss_neuralsde), Vector{Float32}, Vector{Float64}}, Tuple{Zygote.var"#kw_zpullback#53"{DiffEqBase.var"#SDEProblemAdjoint#113"}, Zygote.var"#1956#back#190"{Zygote.var"#186#189"{Zygote.Context{false}, GlobalRef, Matrix{Float64}}}, Zygote.ZBack{ChainRules.var"#sum_abs2_pullback#1682"{Matrix{Float64}}}, Zygote.var"#2573#back#529"{Zygote.var"#539#541"{2, Float64, RODESolution{Float64, 2, Vector{Vector{Float64}}, Nothing, Nothing, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Nothing, SDEProblem{Vector{Float64}, Tuple{Float64, Float64}, false, Vector{Float32}, Nothing, SDEFunction{false, SciMLBase.FullSpecialize, typeof(ratestodrift), typeof(ratestodiff), UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing}, typeof(ratestodiff), Base.Pairs{Symbol, CallbackSet{Tuple{}, Tuple{DiscreteCallback{typeof(condition), SciMLSensitivity.TrackedAffect{Float64, Vector{Float64}, Vector{Float32}, typeof(affect!), Nothing, Int64}, typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}}}, Tuple{Symbol}, NamedTuple{(:callback,), Tuple{CallbackSet{Tuple{}, Tuple{DiscreteCallback{typeof(condition), SciMLSensitivity.TrackedAffect{Float64, Vector{Float64}, Vector{Float32}, typeof(affect!), Nothing, Int64}, typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}}}}}}, Matrix{Float64}}, EM{true}, StochasticDiffEq.LinearInterpolationData{Vector{Vector{Float64}}, Vector{Float64}}, DiffEqBase.Stats, Nothing}, Tuple{Colon, Colon}}}, Zygote.Pullback{Tuple{Type{NamedTuple{(:noise_rate_prototype, :callback)}}, Tuple{Matrix{Float64}, CallbackSet{Tuple{}, Tuple{DiscreteCallback{typeof(condition), typeof(affect!), typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}}}}}, Tuple{Zygote.Pullback{Tuple{Type{NamedTuple{(:noise_rate_prototype, :callback), Tuple{Matrix{Float64}, CallbackSet{Tuple{}, Tuple{DiscreteCallback{typeof(condition), typeof(affect!), typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}}}}}}, Tuple{Matrix{Float64}, CallbackSet{Tuple{}, Tuple{DiscreteCallback{typeof(condition), typeof(affect!), typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}}}}}, Tuple{Zygote.var"#2187#back#311"{Zygote.Jnew{NamedTuple{(:noise_rate_prototype, :callback), Tuple{Matrix{Float64}, CallbackSet{Tuple{}, Tuple{DiscreteCallback{typeof(condition), typeof(affect!), typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}}}}}, Nothing, true}}}}}}, Zygote.Pullback{Tuple{Type{NamedTuple{(:autojacvec, :noisemixing)}}, Tuple{ReverseDiffVJP{false}, Bool}}, Tuple{Zygote.Pullback{Tuple{Type{NamedTuple{(:autojacvec, :noisemixing), Tuple{ReverseDiffVJP{false}, Bool}}}, Tuple{ReverseDiffVJP{false}, Bool}}, Tuple{Zygote.var"#2187#back#311"{Zygote.Jnew{NamedTuple{(:autojacvec, :noisemixing), Tuple{ReverseDiffVJP{false}, Bool}}, Nothing, true}}}}}}, Zygote.Pullback{Tuple{Core.var"#Type##kw", NamedTuple{(:autojacvec, :noisemixing), Tuple{ReverseDiffVJP{false}, Bool}}, Type{InterpolatingAdjoint}}, Any}, Zygote.var"#1983#back#200"{typeof(identity)}, Zygote.Pullback{Tuple{Type{ReverseDiffVJP}}, Tuple{}}, Zygote.var"#1956#back#190"{Zygote.var"#186#189"{Zygote.Context{false}, GlobalRef, Tuple{Float64, Float64}}}, Zygote.var"#1983#back#200"{typeof(identity)}, Zygote.var"#1983#back#200"{typeof(identity)}, Zygote.var"#1956#back#190"{Zygote.var"#186#189"{Zygote.Context{false}, GlobalRef, CallbackSet{Tuple{}, Tuple{DiscreteCallback{typeof(condition), typeof(affect!), typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}}}}}, Zygote.Pullback{Tuple{CommonSolve.var"#solve##kw", NamedTu ...
#     @ Zygote ~/.julia/packages/Zygote/HTsWj/src/compiler/interface2.jl:0
#  [31] (::Zygote.var"#75#76"{Zygote.Pullback{Tuple{var"#5#6", Vector{Float32}}, Tuple{Zygote.var"#1956#back#190"{Zygote.var"#186#189"{Zygote.Context{false}, GlobalRef, Vector{Float64}}}, Zygote.Pullback{Tuple{typeof(loss_neuralsde), Vector{Float32}, Vector{Float64}}, Tuple{Zygote.var"#kw_zpullback#53"{DiffEqBase.var"#SDEProblemAdjoint#113"}, Zygote.var"#1956#back#190"{Zygote.var"#186#189"{Zygote.Context{false}, GlobalRef, Matrix{Float64}}}, Zygote.ZBack{ChainRules.var"#sum_abs2_pullback#1682"{Matrix{Float64}}}, Zygote.var"#2573#back#529"{Zygote.var"#539#541"{2, Float64, RODESolution{Float64, 2, Vector{Vector{Float64}}, Nothing, Nothing, StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, Nothing, SDEProblem{Vector{Float64}, Tuple{Float64, Float64}, false, Vector{Float32}, Nothing, SDEFunction{false, SciMLBase.FullSpecialize, typeof(ratestodrift), typeof(ratestodiff), UniformScaling{Bool}, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, Nothing, typeof(SciMLBase.DEFAULT_OBSERVED), Nothing, Nothing}, typeof(ratestodiff), Base.Pairs{Symbol, CallbackSet{Tuple{}, Tuple{DiscreteCallback{typeof(condition), SciMLSensitivity.TrackedAffect{Float64, Vector{Float64}, Vector{Float32}, typeof(affect!), Nothing, Int64}, typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}}}, Tuple{Symbol}, NamedTuple{(:callback,), Tuple{CallbackSet{Tuple{}, Tuple{DiscreteCallback{typeof(condition), SciMLSensitivity.TrackedAffect{Float64, Vector{Float64}, Vector{Float32}, typeof(affect!), Nothing, Int64}, typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}}}}}}, Matrix{Float64}}, EM{true}, StochasticDiffEq.LinearInterpolationData{Vector{Vector{Float64}}, Vector{Float64}}, DiffEqBase.Stats, Nothing}, Tuple{Colon, Colon}}}, Zygote.Pullback{Tuple{Type{NamedTuple{(:noise_rate_prototype, :callback)}}, Tuple{Matrix{Float64}, CallbackSet{Tuple{}, Tuple{DiscreteCallback{typeof(condition), typeof(affect!), typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}}}}}, Tuple{Zygote.Pullback{Tuple{Type{NamedTuple{(:noise_rate_prototype, :callback), Tuple{Matrix{Float64}, CallbackSet{Tuple{}, Tuple{DiscreteCallback{typeof(condition), typeof(affect!), typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}}}}}}, Tuple{Matrix{Float64}, CallbackSet{Tuple{}, Tuple{DiscreteCallback{typeof(condition), typeof(affect!), typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}}}}}, Tuple{Zygote.var"#2187#back#311"{Zygote.Jnew{NamedTuple{(:noise_rate_prototype, :callback), Tuple{Matrix{Float64}, CallbackSet{Tuple{}, Tuple{DiscreteCallback{typeof(condition), typeof(affect!), typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}}}}}, Nothing, true}}}}}}, Zygote.Pullback{Tuple{Type{NamedTuple{(:autojacvec, :noisemixing)}}, Tuple{ReverseDiffVJP{false}, Bool}}, Tuple{Zygote.Pullback{Tuple{Type{NamedTuple{(:autojacvec, :noisemixing), Tuple{ReverseDiffVJP{false}, Bool}}}, Tuple{ReverseDiffVJP{false}, Bool}}, Tuple{Zygote.var"#2187#back#311"{Zygote.Jnew{NamedTuple{(:autojacvec, :noisemixing), Tuple{ReverseDiffVJP{false}, Bool}}, Nothing, true}}}}}}, Zygote.Pullback{Tuple{Core.var"#Type##kw", NamedTuple{(:autojacvec, :noisemixing), Tuple{ReverseDiffVJP{false}, Bool}}, Type{InterpolatingAdjoint}}, Any}, Zygote.var"#1983#back#200"{typeof(identity)}, Zygote.Pullback{Tuple{Type{ReverseDiffVJP}}, Tuple{}}, Zygote.var"#1956#back#190"{Zygote.var"#186#189"{Zygote.Context{false}, GlobalRef, Tuple{Float64, Float64}}}, Zygote.var"#1983#back#200"{typeof(identity)}, Zygote.var"#1983#back#200"{typeof(identity)}, Zygote.var"#1956#back#190"{Zygote.var"#186#189"{Zygote.Context{false}, GlobalRef, CallbackSet{Tuple{}, Tuple{DiscreteCallback{typeof(condition), typeof(affect!), typeof(SciMLBase.INITIALIZE_DEFAULT), typeof(SciMLBase.FINALIZE_DEFAULT)}}}}}, Zygote.Pullback{Tuple{CommonSolve.var"# ...
#     @ Zygote ~/.julia/packages/Zygote/HTsWj/src/compiler/interface.jl:45
#  [32] gradient(f::Function, args::Vector{Float32})
#     @ Zygote ~/.julia/packages/Zygote/HTsWj/src/compiler/interface.jl:97
#  [33] top-level scope
#     @ In[9]:9
