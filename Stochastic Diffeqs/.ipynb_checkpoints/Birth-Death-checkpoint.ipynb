# %%
using Pkg

# %%
using Plots, Statistics
using Lux, DiffEqFlux, StochasticDiffEq, DiffEqBase.EnsembleAnalysis
using NNlib, Optimisers, Random, Statistics, Zygote
u0 = Float32[2.; 0.]
datasize = 30
tspan = (0.0f0, 10.0f0)
tsteps = range(tspan[1], tspan[2], length = datasize)
# Out:
# 0.0f0:0.3448276f0:10.0f0

# %%
using NamedTuples
# Out:
# ArgumentError: Package NamedTuples not found in current path.
# - Run `import Pkg; Pkg.add("NamedTuples")` to install the NamedTuples package.
#
# Stacktrace:
#  [1] macro expansion
#    @ .\loading.jl:1163 [inlined]
#  [2] macro expansion
#    @ .\lock.jl:223 [inlined]
#  [3] require(into::Module, mod::Symbol)
#    @ Base .\loading.jl:1144

# %% [markdown]
# Starting with the so-called "Birth-Death" system. Will need to define a different set of training data than examples, because we want to capture data of the reactions involved.

# %%
function trueSDEfunc(du, u, p, t)
    R1 = 0.2*u[1]
    R2 = 0.1*u[1]
    du[1] = R1-R2
    du[2] = R1
    du[3] = R2
end

function true_noise_func(du, u, p, t)
    R1 = 0.2*u[1]
    R2 = 0.1*u[1]
    du[1, 1] = sqrt.(R1)[1]
    du[1, 2] = -sqrt.(R2)[1]
    du[2, 1] = sqrt.(R1)[1]
    du[3, 2] = 0
    du[3, 1] = 0
    du[3, 2] = sqrt.(R2)[1]
end
prob_truesde = SDEProblem(trueSDEfunc, true_noise_func, [50,0,0], tspan, noise_rate_prototype = zeros(3, 2))
nothing

# %%
sol = solve(prob_truesde, EM(), dt=0.001)
plot(sol)

# %%
ensembleprob = EnsembleProblem(prob_truesde)
@time sol = solve(ensembleprob, EM(), dt=0.05, saveat = 0.1, trajectories = 1000)
truemean = mean(sol, dims = 3)[:, :]
truevar = var(sol, dims = 3)[:, :]
# Out:
#   1.426543 seconds (3.34 M allocations: 167.065 MiB, 3.31% gc time, 93.60% compilation time)
# 3×101 Matrix{Float64}:
#  0.0  1.45324   3.04219   4.67942  …  541.526  559.531  573.356  585.395
#  0.0  1.01237   2.10418   3.15793     879.52   912.065  939.898  966.419
#  0.0  0.496598  0.972814  1.42105     109.674  113.519  116.197  122.143

# %%
plot(LinRange(0,10,101),truemean')

# %%
plot(LinRange(0,10,101),truevar')

# %%
rng = Random.default_rng()
# Out:
# TaskLocalRNG()

# %%
function ratestodrift(R)
    R1,R2 = (R) for R0 in R)
    return [R1-R2,R1,R2]
end

function ratestodiff(R)
    R1,R2 = (abs(R0) for R0 in R)
    return [[sqrt.(R1),sqrt.(R1),0] [-sqrt.(R2),0,sqrt.(R2)]]
end
# Out:
# syntax: "function" at In[310]:1 expected "end", got "for"
#
# Stacktrace:
#  [1] top-level scope
#    @ In[310]:2

# %%
ratesmodel = Lux.Chain((x -> [x[1]]),Lux.Dense(1 => 16, relu), Lux.Dense(16 => 2))
p1, st1 = Lux.setup(rng, ratesmodel)
#neuralsde = NeuralDSDE(drift_dudt, diffusion_dudt, tspan, SOSRI(),saveat = tsteps, reltol = 1e-1, abstol = 1e-1)
#nothing
# Out:
# ((layer_1 = NamedTuple(), layer_2 = (weight = Float32[-0.001106222; 0.28274405; … ; 0.009844173; 0.25736788;;], bias = Float32[0.0; 0.0; … ; 0.0; 0.0;;]), layer_3 = (weight = Float32[0.38928166 0.5436872 … -0.2419826 -0.4753475; -0.048681937 0.38799393 … 0.0990543 -0.12974001], bias = Float32[0.0; 0.0;;])), (layer_1 = NamedTuple(), layer_2 = NamedTuple(), layer_3 = NamedTuple()))

# %%
ratesmodel([1],p1,st1)
# Out:
# (Float32[-0.067532115, -0.1564388], (layer_1 = NamedTuple(), layer_2 = NamedTuple(), layer_3 = NamedTuple()))

# %%
ratesmodel
# Out:
# Chain(
#     layer_1 = WrappedFunction(#69),
#     layer_2 = Dense(1 => 16, relu),     # 32 parameters
#     layer_3 = Dense(16 => 2),           # 34 parameters
# )         # Total: 66 parameters,
#           #        plus 0 states, summarysize 32 bytes.

# %%
driftmodel = Lux.Chain(ratesmodel,(x -> ratestodrift(x)))
p2, st2 = Lux.setup(rng, driftmodel)

diffmodel = Lux.Chain(ratesmodel,(x -> ratestodiff(x)))
p3, st3 = Lux.setup(rng, driftmodel)
# Out:
# ((layer_1 = NamedTuple(), layer_2 = (weight = Float32[0.24630219; -0.07960465; … ; 0.21210271; -0.5919971;;], bias = Float32[0.0; 0.0; … ; 0.0; 0.0;;]), layer_3 = (weight = Float32[0.2488997 -0.13474831 … -0.06926964 0.5012313; 0.018795973 -0.10564875 … 0.4590125 0.35352844], bias = Float32[0.0; 0.0;;]), layer_4 = NamedTuple()), (layer_1 = NamedTuple(), layer_2 = NamedTuple(), layer_3 = NamedTuple(), layer_4 = NamedTuple()))

# %%
driftmodel
# Out:
# Chain(
#     layer_1 = WrappedFunction(#69),
#     layer_2 = Dense(1 => 16, relu),     # 32 parameters
#     layer_3 = Dense(16 => 2),           # 34 parameters
#     layer_4 = WrappedFunction(#71),
# )         # Total: 66 parameters,
#           #        plus 0 states, summarysize 32 bytes.

# %%
driftmodel([1,2,3,4],p2,st2)
# Out:
# (Float32[-0.24663273, 0.11374184, 0.36037457], (layer_1 = NamedTuple(), layer_2 = NamedTuple(), layer_3 = NamedTuple(), layer_4 = NamedTuple()))

# %%
diffmodel([1;2;3],p3,st3)
# Out:
# (Float32[0.16927256 -0.6211373; 0.16927256 0.0; 0.0 0.6211373], (layer_1 = NamedTuple(), layer_2 = NamedTuple(), layer_3 = NamedTuple(), layer_4 = NamedTuple()))

# %%
neuralsde = NeuralSDE(driftmodel,diffmodel,tspan,2,alg=EM(),dt = 0.05)
# Out:
# NeuralSDE(
#     drift = Chain(
#         layer_1 = WrappedFunction(#69),
#         layer_2 = Dense(1 => 16, relu),  # 32 parameters
#         layer_3 = Dense(16 => 2),       # 34 parameters
#         layer_4 = WrappedFunction(#71),
#     ),
#     diffusion = Chain(
#         layer_1 = WrappedFunction(#69),
#         layer_2 = Dense(1 => 16, relu),  # 32 parameters
#         layer_3 = Dense(16 => 2),       # 34 parameters
#         layer_4 = WrappedFunction(#73),
#     ),
# )         # Total: 132 parameters,
#           #        plus 0 states, summarysize 152 bytes.

# %%
p4, st4 = Lux.setup(rng, neuralsde)
# Out:
# ((drift = (layer_1 = NamedTuple(), layer_2 = (weight = Float32[-0.43978304; -0.574277; … ; -0.2759066; -0.56505615;;], bias = Float32[0.0; 0.0; … ; 0.0; 0.0;;]), layer_3 = (weight = Float32[0.15333588 -0.25212884 … 0.4870079 -0.49201226; -0.29471347 -0.32022908 … 0.19785291 0.2602586], bias = Float32[0.0; 0.0;;]), layer_4 = NamedTuple()), diffusion = (layer_1 = NamedTuple(), layer_2 = (weight = Float32[0.022727836; 0.22831708; … ; 0.39892563; 0.44538093;;], bias = Float32[0.0; 0.0; … ; 0.0; 0.0;;]), layer_3 = (weight = Float32[0.48586065 -0.48714533 … 0.13878988 -0.17694338; 0.34300235 0.47400585 … -0.46666142 -0.24762154], bias = Float32[0.0; 0.0;;]), layer_4 = NamedTuple())), (drift = (layer_1 = NamedTuple(), layer_2 = NamedTuple(), layer_3 = NamedTuple(), layer_4 = NamedTuple()), diffusion = (layer_1 = NamedTuple(), layer_2 = NamedTuple(), layer_3 = NamedTuple(), layer_4 = NamedTuple())))

# %%
typeof(p4)
# Out:
# NamedTuple{(:drift, :diffusion), Tuple{NamedTuple{(:layer_1, :layer_2, :layer_3, :layer_4), Tuple{NamedTuple{(), Tuple{}}, NamedTuple{(:weight, :bias), Tuple{Matrix{Float32}, Matrix{Float32}}}, NamedTuple{(:weight, :bias), Tuple{Matrix{Float32}, Matrix{Float32}}}, NamedTuple{(), Tuple{}}}}, NamedTuple{(:layer_1, :layer_2, :layer_3, :layer_4), Tuple{NamedTuple{(), Tuple{}}, NamedTuple{(:weight, :bias), Tuple{Matrix{Float32}, Matrix{Float32}}}, NamedTuple{(:weight, :bias), Tuple{Matrix{Float32}, Matrix{Float32}}}, NamedTuple{(), Tuple{}}}}}}

# %%
p4alt = @NT(drift = p2, diffusion = p3)
# Out:
# LoadError: UndefVarError: @NT not defined
# in expression starting at In[361]:1

# %%
u0 = Float32[50;0;0]
# Out:
# 3-element Vector{Float32}:
#  50.0
#   0.0
#   0.0

# %%
solmaybe = neuralsde(u0,p4,st4)
plot(solmaybe[1].t,Array(solmaybe[1])')

# %%
ratesmodel([1],p1,st1)

# %%
typeof(ratesmodel)

# %%
drift_dudt

# %%
drift_dudt([1],rand(100))

# %%
rand(50)
